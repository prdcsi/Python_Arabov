# %% [markdown]
# <a href="https://colab.research.google.com/github/prdcsi/Python_Arabov/blob/main/Git.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
git init

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.00.02.png](data:image/png;base64,...)

# %%
git add test.txt

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.07.08.png](data:image/png;base64,...)

# %%
git commit -m "Добавлен файл с описанием"

# %% [markdown]
# > Добавить блок с цитатой![Снимок экрана 2025-10-12 в 11.08.31.png](data:image/png;base64,...)

# %%
git log

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.10.38.png](data:image/png;base64,...)

# %%
git diff

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.12.42.png](data:image/png;base64,...)

# %%
git checkout -- test.txt

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.13.52.png](data:image/png;base64,...)

# %%
git branch test

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.14.40.png](data:image/png;base64,...)

# %%
git checkout test

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.15.23.png](data:image/png;base64,...)

# %%
git checkout main
git merge test

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.16.36.png](data:image/png;base64,...)

# %%
git branch -d test

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.17.54.png](data:image/png;base64,...)

# %%
git commit --amend -m "Исправление опечатки"

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.18.54.png](data:image/png;base64,...)

# %%
git rm test.txt

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.21.01.png](data:image/png;base64,...)

# %%
echo "node_modules/" >> .gitignore
echo "*.log" >> .gitignore

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.23.22.png](data:image/png;base64,...)

# %%
git diff main test_2

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.24.49.png](data:image/png;base64,...)

# %%
git reset HEAD delete_file.txt

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.25.46.png](data:image/png;base64,...)

# %%
git status

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.33.19.png](data:image/png;base64,...)

# %%
git mv "delete_file.txt" "delete.txt"

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.35.08.png](data:image/png;base64,...)

# %%
git show b2669c2

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.37.08.png](data:image/png;base64,...)

# %%
git checkout b2669c2

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.38.09.png](data:image/png;base64,...)

# %%
git format-patch -1 HEAD
git apply 0001-.patch

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.39.54.png](data:image/png;base64,...)

# %%
git commit --amend --author="Иван Иванов <ivan@example.com>"

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.41.14.png](data:image/png;base64,...)

# %%
git stash
git stash apply

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
git cherry-pick b2669c2

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.47.37.png](data:image/png;base64,...)

# %%
git branch -a
git remote -v

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.48.51.png](data:image/png;base64,...)

# %%
git remote set-url origin https://github.com/prdcsi/Python_Arabov.git

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.51.44.png](data:image/png;base64,...)

# %%
git reset HEAD

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.52.58.png](data:image/png;base64,...)

# %%
git config --global alias.st status
git config --global alias.co checkout

# %% [markdown]
# ![Снимок экрана 2025-10-12 в 11.53.53.png](data:image/png;base64,...)

# %%
git submodule add https://github.com/prdcsi/Python_Arabov.git libs/Python_Arabov
git add .gitmodules libs/Python_Arabov
git commit -m "Добавлен подмодуль Python_Arabov"

# %% [markdown]
# ![image.png](data:image/png;base64,...)
